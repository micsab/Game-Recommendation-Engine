# %%
import seaborn as sns
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup as soup, SoupStrainer
import requests
import lxml
from collections import Counter
from requests import exceptions
import os
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import steam
import pandas as pd
import numpy as np
from rake_nltk import Rake
import matplotlib.pyplot as plt; plt.rcdefaults()
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
from steam.api import interface
steam.api.key.set('FC864146AEF094845C669F86F0B20CFF')
pd.options.display.float_format = '{:,.5f}'.format
pd.set_option('display.max_colwidth', 80)
# %matplotlib inline

# %%
# Get title and links for all steam games
#urls = ['https://store.steampowered.com/search/?category1=998&page={}'.format(i) for i in range(1, 1185)]

filename = "products_v2.csv"
f = open(filename, "w", encoding="utf-8")
headers = "game_title\tsteam_url\n"
f.write(headers)

for url in urls:
    r = requests.get(url)
    page_soup = soup(r.content, "html.parser")

    containers = page_soup.findAll("a", {"class":"search_result_row ds_collapse_flag "})

    for container in containers:
        game_title = container.findAll("span", {"class":"title"})[0].text
        link = container["href"]

        #print(game_title)
        #print(link)
        #print("----------------")

        f.write(game_title + "\t" + link + "\n")

f.close()

# %% [markdown]
# # Don't Run This It'll Take Like a Million Hours#

# %%
#df_links = pd.read_csv('products_v2.csv', delimiter="\t")

tags = []
images = []
descriptions = []
num_reviews = []
rating_values = []
releases = []

cookies = {'birthtime': '568022401'}

for link in df_links.iterrows():
    print(link[1]['game_title'])
    url = link[1]['steam_url']
    r = requests.get(url, cookies=cookies)
    page_soup = soup(r.content, 'lxml')
    try:
        tag = page_soup.find("div", {"class":"glance_tags popular_tags"})
        tag = tag.text
        tag = tag.replace('\t', '').replace('\r', '').replace('\n', ', ').replace('+, ', '').replace(', , ', '')
        tags.append(tag)
    except:
        tag = 'no tags'
        tags.append(tag)
    
    try:
        image = page_soup.find('img', {'class':'game_header_image_full'})['src']
        images.append(image)
    except:
        image = 'no_image'
        images.append(image)
    
    try:
        num_review = int(page_soup.find('meta', {'itemprop':'reviewCount'})['content'])
        num_reviews.append(num_review)
    except:
        num_review = 'no reviews'
        num_reviews.append(num_review)

    try:
        rating_value = float(page_soup.find('meta', {'itemprop':'ratingValue'})['content'])
        rating_values.append(rating_value)
    except:
        rating_value = 'no rating'
        rating_values.append(rating_value)
    
    try:
        description = page_soup.find('div', {'class': 'game_description_snippet'}).text.replace('\t','').replace('\r','').replace('\n', '')
        descriptions.append(description)
    except:
        description = 'no description'
        descriptions.append(description)
        
    try:
        release = page_soup.find('div', {'class': 'date'}).text
        releases.append(release)
    except:
        release = 'no release date'
        releases.append(release)

        
        
    
      
the_rest = pd.DataFrame({'tags': tags, 'image': images, 'description': descriptions,
                         'number_of_review': num_reviews,
                         'score': rating_values,
                         'release_date': releases})

steam_scrape_the_rest = pd.concat([df_links, the_rest], axis=1, sort=False)
steam_scrape_the_rest.to_csv('steam_games_all_fields.csv', sep='\t')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-f0b7386d0a38> in <module>()
#      10 cookies = {'birthtime': '568022401'}
#      11
# ---> 12 for link in df_links.iterrows():
#      13     print(link[1]['game_title'])
#      14     url = link[1]['steam_url']
#
# NameError: name 'df_links' is not defined

# %%
steam_games = pd.read_csv('steam_games_all_fields.csv', index_col=0, delimiter='\t')
app_id = steam_games['steam_url'].str.split('/',expand=True)
app_id = app_id.drop([0, 1, 2, 5, 6], axis=1)
app_id.columns = ['app', 'game_ID']
df = pd.concat([steam_games, app_id], axis=1, sort=False)
df['description'] = df['description'].fillna('')
df = df[~df.description.str.contains('no description')]
df['release_date'] = df['release_date'].replace({'no release date' : ''})
df['game_title'] = df['game_title'].str.replace(r'®', '')
df['game_title'] = df['game_title'].str.replace(r'™', '')
df = df.drop(['app'], axis=1)
df['game_ID'] = pd.to_numeric(df['game_ID'], downcast='signed')
df['number_of_review'] = df['number_of_review'].replace({'no reviews' : ''})
df['number_of_review'] = pd.to_numeric(df['number_of_review'], downcast='integer')
df['score'] = df['score'].replace({'no rating' : ''})
df['score'] = pd.to_numeric(df['score'])
df = df[df['number_of_review'] > 0]
df = df.rename(columns={"game_ID": "appid"})
df = df.rename(columns={"Unnamed: 0": "id"})
#df = df.drop(['steam_url', 'image'], axis=1)
df = df.drop_duplicates(subset='appid', keep='first')
df = df.dropna(subset=['game_title'])
df = df.reset_index()
df.head()
# Out:
#    index                        game_title                                                                                   steam_url                                                                                                                                                                                                                                                 tags                                                                      image                                                                                                                                                                                                                                                                          description  number_of_review   score  release_date   appid
# 0      0  Counter-Strike: Global Offensive  https://store.steampowered.com/app/730/CounterStrike_Global_Offensive/?snr=1_7_7_230_150_1                                                 FPS, Multiplayer, Shooter, Action, Team-Based, Competitive, Tactical, First-Person, e-sports, PvP, Online Co-Op, Military, Co-op, Strategy, War, Trading, Difficult, Realistic, Fast-Paced, Moddable     https://steamcdn-a.akamaihd.net/steam/apps/730/header.jpg?t=1544148568  Counter-Strike: Global Offensive (CS: GO) expands upon the team-based action gameplay that it pioneered when it was launched 19 years ago. CS: GO features new maps, characters, weapons, and game modes, and delivers updated versions of the classic CS content (de_dust2, etc.).   2,915,091.00000 9.00000  Aug 21, 2012     730
# 1      1             MONSTER HUNTER: WORLD         https://store.steampowered.com/app/582010/MONSTER_HUNTER_WORLD/?snr=1_7_7_230_150_1     Action, Hunting, Co-op, Open World, Multiplayer, Third Person, RPG, Adventure, Fantasy, Singleplayer, Action RPG, Character Customization, Difficult, Great Soundtrack, Exploration, Atmospheric, JRPG, Replay Value, Hack and Slash, Souls-like  https://steamcdn-a.akamaihd.net/steam/apps/582010/header.jpg?t=1544082685                                      Welcome to a new world! In Monster Hunter: World, the latest installment in the series, you can enjoy the ultimate hunting experience, using everything at your disposal to hunt monsters in a new world teeming with surprises and excitement.      55,314.00000 6.00000   Aug 9, 2018  582010
# 2      2                     Path of Exile                https://store.steampowered.com/app/238960/Path_of_Exile/?snr=1_7_7_230_150_1  Free to Play, Action RPG, Hack and Slash, RPG, Multiplayer, Massively Multiplayer, Action, Loot, Fantasy, Adventure, MMORPG, Indie, Dungeon Crawler, Online Co-Op, Co-op, Character Customization, PvE, Dark Fantasy, Inventory Management, Fishing  https://steamcdn-a.akamaihd.net/steam/apps/238960/header.jpg?t=1544390585       You are an Exile, struggling to survive on the dark continent of Wraeclast, as you fight to earn power that will allow you to exact your revenge against those who wronged you. Created by hardcore gamers, Path of Exile is an online Action RPG set in a dark fantasy world.      74,977.00000 9.00000  Oct 23, 2013  238960
# 3      3             Insurgency: Sandstorm         https://store.steampowered.com/app/581320/Insurgency_Sandstorm/?snr=1_7_7_230_150_1                              FPS, Realistic, Shooter, Multiplayer, Action, Military, Tactical, Singleplayer, First-Person, War, Online Co-Op, Atmospheric, Violent, Co-op, Difficult, Gore, Open World, Massively Multiplayer, Choices Matter, Indie  https://steamcdn-a.akamaihd.net/steam/apps/581320/header.jpg?t=1546538316                                               Insurgency: Sandstorm is a team-based, tactical FPS based on lethal close quarters combat and objective-oriented multiplayer gameplay. Experience the intensity of modern combat where skill is rewarded, and teamwork wins the fight.       9,019.00000 9.00000  Dec 12, 2018  581320
# 4      4                          Warframe                     https://store.steampowered.com/app/230410/Warframe/?snr=1_7_7_230_150_1                        Free to Play, Action, Co-op, Multiplayer, Third-Person Shooter, Sci-fi, Ninja, Shooter, Parkour, Space, Online Co-Op, Futuristic, Third Person, Massively Multiplayer, PvE, RPG, Singleplayer, Hack and Slash, FPS, Cyberpunk  https://steamcdn-a.akamaihd.net/steam/apps/230410/header.jpg?t=1545251372                                                                                                                                                                              Warframe is a cooperative free-to-play third person online action game set in an evolving sci-fi world.     236,593.00000 9.00000  Mar 25, 2013  230410

# %%
text = " ".join(desc for desc in df.description)
print ("There are {} words in the combination of all descriptions.".format(len(text)))
stopwords = set(STOPWORDS)
#d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()
#video_mask = np.array(Image.open(path.join(d, "video_games.png")))
wc = WordCloud(stopwords=stopwords, width=1800, height=900, background_color="white", max_words=10000,
                      contour_width=1, contour_color='white').generate(text)

#wc.to_file(path.join(d, 'video_games.png'))

plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# There are 4213412 words in the combination of all descriptions.

# %%
text = " ".join(desc for desc in df.tags)
textlist = text.split(", ")
wordfreq = [textlist.count(w) for w in textlist]
pairs = Counter(text.split(", ")).most_common(25)
word = []
frequency = []

for i in range(len(pairs)):
    word.append(pairs[i][0])
    frequency.append(pairs[i][1])

indices = np.arange(len(pairs))
plt.bar(indices, frequency)
plt.title('Steam Tags by Count')
plt.xticks(indices, word, rotation='vertical')
plt.tight_layout()
plt.show()

# %%
games = interface('IPlayerService').GetOwnedGames(steamid=76561197974553664, include_appinfo=1)
my_games = games['response']['games']
game_table = pd.DataFrame(my_games)
game_table = game_table.drop(['has_community_visible_stats', 'playtime_2weeks',
                              'img_icon_url', 'img_logo_url'], axis=1)
my_games_info = pd.merge(df, game_table, on='appid')
not_my_games = pd.merge(df, game_table, how='outer', on='appid')
not_my_games = not_my_games[not_my_games['playtime_forever'].isnull()]
not_my_games = not_my_games.drop(['name', 'image', 'playtime_forever'], axis=1)
not_my_games.head()
# Out:
#     index                                     game_title                                                                                                   steam_url                                                                                                                                                                                                                                                                 tags                                                                                                                                                                                                                                                                     description  number_of_review   score  release_date   appid
# 1 1.00000  MONSTER HUNTER: WORLD                          https://store.steampowered.com/app/582010/MONSTER_HUNTER_WORLD/?snr=1_7_7_230_150_1                         Action, Hunting, Co-op, Open World, Multiplayer, Third Person, RPG, Adventure, Fantasy, Singleplayer, Action RPG, Character Customization, Difficult, Great Soundtrack, Exploration, Atmospheric, JRPG, Replay Value, Hack and Slash, Souls-like                     Welcome to a new world! In Monster Hunter: World, the latest installment in the series, you can enjoy the ultimate hunting experience, using everything at your disposal to hunt monsters in a new world teeming with surprises and excitement.                                55,314.00000      6.00000  Aug 9, 2018   582010
# 2 2.00000  Path of Exile                                  https://store.steampowered.com/app/238960/Path_of_Exile/?snr=1_7_7_230_150_1                                Free to Play, Action RPG, Hack and Slash, RPG, Multiplayer, Massively Multiplayer, Action, Loot, Fantasy, Adventure, MMORPG, Indie, Dungeon Crawler, Online Co-Op, Co-op, Character Customization, PvE, Dark Fantasy, Inventory Management, Fishing                  You are an Exile, struggling to survive on the dark continent of Wraeclast, as you fight to earn power that will allow you to exact your revenge against those who wronged you. Created by hardcore gamers, Path of Exile is an online Action RPG set in a dark fantasy world. 74,977.00000      9.00000  Oct 23, 2013  238960
# 3 3.00000  Insurgency: Sandstorm                          https://store.steampowered.com/app/581320/Insurgency_Sandstorm/?snr=1_7_7_230_150_1                         FPS, Realistic, Shooter, Multiplayer, Action, Military, Tactical, Singleplayer, First-Person, War, Online Co-Op, Atmospheric, Violent, Co-op, Difficult, Gore, Open World, Massively Multiplayer, Choices Matter, Indie                                              Insurgency: Sandstorm is a team-based, tactical FPS based on lethal close quarters combat and objective-oriented multiplayer gameplay. Experience the intensity of modern combat where skill is rewarded, and teamwork wins the fight.                                         9,019.00000       9.00000  Dec 12, 2018  581320
# 4 4.00000  Warframe                                       https://store.steampowered.com/app/230410/Warframe/?snr=1_7_7_230_150_1                                     Free to Play, Action, Co-op, Multiplayer, Third-Person Shooter, Sci-fi, Ninja, Shooter, Parkour, Space, Online Co-Op, Futuristic, Third Person, Massively Multiplayer, PvE, RPG, Singleplayer, Hack and Slash, FPS, Cyberpunk                                        Warframe is a cooperative free-to-play third person online action game set in an evolving sci-fi world.                                                                                                                                                                        236,593.00000     9.00000  Mar 25, 2013  230410
# 5 5.00000  Divinity: Original Sin 2 - Definitive Edition  https://store.steampowered.com/app/435150/Divinity_Original_Sin_2__Definitive_Edition/?snr=1_7_7_230_150_1  RPG, Turn-Based, Co-op, Story Rich, Fantasy, Open World, Character Customization, Adventure, Strategy, Turn-Based Combat, Singleplayer, Multiplayer, CRPG, Great Soundtrack, Atmospheric, Turn-Based Tactics, Isometric, Party-Based RPG, Indie, Female Protagonist  The eagerly anticipated sequel to the award-winning RPG. Gather your party. Master deep, tactical combat. Join up to 3 other players - but know that only one of you will have the chance to become a God.                                                                     37,446.00000      9.00000  Sep 14, 2017  435150

# %%
df_csno = my_games_info[~my_games_info.game_title.str.contains('Counter-Strike: Global Offensive')]
df_csno = my_games_info[my_games_info['playtime_forever'] <= 8000]

ax = sns.scatterplot(x="playtime_forever", y="number_of_review", hue="score", 
                     data=df_csno)

# %%
ax = sns.violinplot(x="score", y="playtime_forever", data=my_games_info)

# %%
tfidf_vec_desc = df[['index' ,'appid', 'game_title', 'tags', 'description']]
tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(tfidf_vec_desc['description'])
cosine_similarities = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
results_desc = {}

for idx, row in tfidf_vec_desc.iterrows():
    similar_indices = cosine_similarities[idx].argsort()[:-1000:-1]
    similar_items = [(cosine_similarities[idx][i], tfidf_vec_desc['appid'][i]) for i in similar_indices]

    # First item is the item itself, so remove it.
    # Each dictionary entry is like: [(1,2), (3,4)], with each tuple being (score, item_id)
    results_desc[row['appid']] = similar_items[1:]
    
print('done!')
# Out:
# done!

# %%
def recommend(game, num):
    app_id = tfidf_vec_desc.loc[tfidf_vec_desc['game_title'] == game]['appid'].tolist()[0]
    
    print('Recommending ' + str(num) + " games sitting in your Steam library unplayed, that are similar to " + 
          item(app_id) + '.')

    rez = results_desc[app_id]
    #print(rez)
    sim_score_df = pd.DataFrame(rez, columns=['sim_score', 'appid'])
    #print(df_test)
    my_game_df = pd.merge(sim_score_df, my_games_info, how='inner', on='appid')
    my_game_df = my_game_df.drop(['index', 'appid', 'number_of_review', 'release_date', 'name', 'score',
                                  'tags', 'description', 'steam_url', 'image'], axis = 1)
    my_game_df = my_game_df[my_game_df['playtime_forever'] <= 60]
    my_game_df = my_game_df.sort_values(['sim_score'], ascending=False)
    return my_game_df.head(num)

recommend('Rocket League', 5)
# Out:
# Recommending 5 games sitting in your Steam library unplayed, that are similar to Rocket League.
#    sim_score                             game_title  playtime_forever
# 0    0.01548                Trine 2: Complete Story                 0
# 1    0.01334                Trine Enchanted Edition                 0
# 2    0.01242  Lead and Gold: Gangs of the Wild West                41
# 3    0.01100                                   BEEP                 7
# 4    0.01046                     TrackMania² Canyon                 6

# %%
def recommend(game, num):
    app_id = tfidf_vec_desc.loc[tfidf_vec_desc['game_title'] == game]['appid'].tolist()[0]
    
    print('Fine, here are ' + str(num) + " games you could buy that are similar to " + 
          item(app_id) + '.')

    rez = results_desc[app_id]
    #print(rez)
    sim_score_df = pd.DataFrame(rez, columns=['sim_score', 'appid'])
    #print(df_test)
    my_game_df = pd.merge(sim_score_df, not_my_games, how='inner', on='appid')
    my_game_df = my_game_df.drop(['index', 'appid', 'number_of_review', 'release_date', 'score',
                                  'tags', 'description'], axis = 1)
    #my_game_df = my_game_df[my_game_df['playtime_forever'] <= 60]
    my_game_df = my_game_df.sort_values(['sim_score'], ascending=False)
    return my_game_df.head(num)

recommend('Rocket League', 5)
# Out:
# Fine, here are 5 games you could buy that are similar to Rocket League.
#    sim_score               game_title                                                                        steam_url
# 0    0.04882          Aerial Guardian  https://store.steampowered.com/app/885730/Aerial_Guardian/?snr=1_7_7_230_150...
# 1    0.04827  Street Fighter X Tekken  https://store.steampowered.com/app/209120/Street_Fighter_X_Tekken/?snr=1_7_7...
# 2    0.04710                Blueshift       https://store.steampowered.com/app/565030/Blueshift/?snr=1_7_7_230_150_302
# 3    0.04594            Glider Island   https://store.steampowered.com/app/500110/Glider_Island/?snr=1_7_7_230_150_248
# 4    0.04101              Rocket Fist     https://store.steampowered.com/app/413500/Rocket_Fist/?snr=1_7_7_230_150_541

# %%
tfidf_vec_tags = df[['index' ,'appid', 'game_title', 'tags', 'description']]
tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), min_df=0)
tfidf_matrix = tf.fit_transform(tfidf_vec_tags['tags'])
cosine_similarities = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
results_tags = {}

for idx, row in tfidf_vec_tags.iterrows():
    similar_indices = cosine_similarities[idx].argsort()[:-1000:-1]
    similar_items = [(cosine_similarities[idx][i], tfidf_vec_tags['appid'][i]) for i in similar_indices]

    # First item is the item itself, so remove it.
    # Each dictionary entry is like: [(1,2), (3,4)], with each tuple being (score, item_id)
    results_tags[row['appid']] = similar_items[1:]
    
print('done!')
# Out:
# done!

# %%
def recommend(game, num):
    app_id = tfidf_vec_tags.loc[tfidf_vec_tags['game_title'] == game]['appid'].tolist()[0]
    
    print('Recommending ' + str(num) + " games sitting in your Steam library unplayed, that are similar to " + 
          item(app_id) + '.')

    rez = results_tags[app_id]
    #print(rez)
    sim_score_df = pd.DataFrame(rez, columns=['sim_score', 'appid'])
    #print(df_test)
    my_game_df = pd.merge(sim_score_df, my_games_info, how='inner', on='appid')
    my_game_df = my_game_df.drop(['index', 'appid', 'number_of_review', 'release_date', 'name', 'score',
                                  'tags', 'description', 'steam_url', 'image'], axis = 1)
    my_game_df = my_game_df[my_game_df['playtime_forever'] <= 60]
    my_game_df = my_game_df.sort_values(['sim_score'], ascending=False)
    return my_game_df.head(num)

recommend('Rocket League', 5)
# Out:
# Recommending 5 games sitting in your Steam library unplayed, that are similar to Rocket League.
#    sim_score                  game_title  playtime_forever
# 1    0.18697               Lethal League                 0
# 4    0.16842          Mount Your Friends                14
# 6    0.14844     Trine 2: Complete Story                 0
# 7    0.14823     Trine Enchanted Edition                 0
# 8    0.14654  Awesomenauts - the 2D moba                 1

# %%
def recommend(game, num):
    app_id = tfidf_vec_tags.loc[tfidf_vec_tags['game_title'] == game]['appid'].tolist()[0]
    
    print('Fine, here are ' + str(num) + " games you could buy that are similar to " + 
          item(app_id) + '.')

    rez = results_tags[app_id]
    #print(rez)
    sim_score_df = pd.DataFrame(rez, columns=['sim_score', 'appid'])
    #print(df_test)
    my_game_df = pd.merge(sim_score_df, not_my_games, how='inner', on='appid')
    my_game_df = my_game_df.drop(['index', 'appid', 'number_of_review', 'release_date', 'score',
                                  'tags', 'description'], axis = 1)
    #my_game_df = my_game_df[my_game_df['playtime_forever'] <= 60]
    my_game_df = my_game_df.sort_values(['sim_score'], ascending=False)
    return my_game_df.head(num)

recommend('Rocket League', 5)
# Out:
# Fine, here are 5 games you could buy that are similar to Rocket League.
#    sim_score          game_title                                                                        steam_url
# 0    0.30604     Squirrel Sphere  https://store.steampowered.com/app/776790/Squirrel_Sphere/?snr=1_7_7_230_150...
# 1    0.27718      Domain Defense  https://store.steampowered.com/app/455960/Domain_Defense/?snr=1_7_7_230_150_858
# 2    0.26751               Chase           https://store.steampowered.com/app/867390/Chase/?snr=1_7_7_230_150_526
# 3    0.24647  3..2..1..Grenades!     https://store.steampowered.com/app/504090/321Grenades/?snr=1_7_7_230_150_507
# 4    0.24193       Overcooked! 2      https://store.steampowered.com/app/728880/Overcooked_2/?snr=1_7_7_230_150_2

# %%
df['tag_desc'] = df[['tags', 'description']].apply(lambda x: ''.join(x), axis=1)
tfidf_vec_tag_desc = df[['index' ,'appid', 'game_title', 'tag_desc']]
tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(tfidf_vec_tag_desc['tag_desc'])
cosine_similarities = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
results_tags_desc = {}

for idx, row in tfidf_vec_tag_desc.iterrows():
    similar_indices = cosine_similarities[idx].argsort()[:-1000:-1]
    similar_items = [(cosine_similarities[idx][i], tfidf_vec_tag_desc['appid'][i]) for i in similar_indices]

    # First item is the item itself, so remove it.
    # Each dictionary entry is like: [(1,2), (3,4)], with each tuple being (score, item_id)
    results_tags_desc[row['appid']] = similar_items[1:]
    
print('done!')
# Out:
# done!

# %%
def recommend(game, num):
    app_id = tfidf_vec_tag_desc.loc[tfidf_vec_tag_desc['game_title'] == game]['appid'].tolist()[0]
    
    print('Recommending ' + str(num) + " games sitting in your Steam library unplayed, that are similar to " + 
          item(app_id) + '.')

    rez = results_tags_desc[app_id]
    #print(rez)
    sim_score_df = pd.DataFrame(rez, columns=['sim_score', 'appid'])
    #print(df_test)
    my_game_df = pd.merge(sim_score_df, my_games_info, how='inner', on='appid')
    my_game_df = my_game_df.drop(['index', 'appid', 'number_of_review', 'release_date', 'name', 'score',
                                  'tags', 'description', 'steam_url', 'image'], axis = 1)
    my_game_df = my_game_df[my_game_df['playtime_forever'] <= 60]
    my_game_df = my_game_df.sort_values(['sim_score'], ascending=False)
    return my_game_df.head(num)

recommend('Rocket League', 5)
# Out:
# Recommending 5 games sitting in your Steam library unplayed, that are similar to Rocket League.
#    sim_score                    game_title  playtime_forever
# 2    0.05799                 Lethal League                 0
# 3    0.05543       Trine Enchanted Edition                 0
# 4    0.05369       Trine 2: Complete Story                 0
# 6    0.05240  Monaco: What's Yours Is Mine                 0
# 7    0.04938    Awesomenauts - the 2D moba                 1

# %%
def recommend(game, num):
    app_id = tfidf_vec_tag_desc.loc[tfidf_vec_tag_desc['game_title'] == game]['appid'].tolist()[0]
    
    print('Fine, here are ' + str(num) + " games you could buy that are similar to " + 
          item(app_id) + '.')

    rez = results_tags_desc[app_id]
    #print(rez)
    sim_score_df = pd.DataFrame(rez, columns=['sim_score', 'appid'])
    #print(df_test)
    my_game_df = pd.merge(sim_score_df, not_my_games, how='inner', on='appid')
    my_game_df = my_game_df.drop(['index', 'appid', 'number_of_review', 'release_date', 'score',
                                  'tags', 'description'], axis = 1)
    #my_game_df = my_game_df[my_game_df['playtime_forever'] <= 60]
    my_game_df = my_game_df.sort_values(['sim_score'], ascending=False)
    return my_game_df.head(num)

recommend('Rocket League', 5)
# Out:
# Fine, here are 5 games you could buy that are similar to Rocket League.
#    sim_score                          game_title                                                                        steam_url
# 0    0.08741               Stick Fight: The Game  https://store.steampowered.com/app/674940/Stick_Fight_The_Game/?snr=1_7_7_23...
# 1    0.08708       Lance A Lot: Enhanced Edition  https://store.steampowered.com/app/684530/Lance_A_Lot_Enhanced_Edition/?snr=...
# 2    0.08641  Robot Roller-Derby Disco Dodgeball  https://store.steampowered.com/app/270450/Robot_RollerDerby_Disco_Dodgeball/...
# 3    0.08316                       Paddle Battle   https://store.steampowered.com/app/655630/Paddle_Battle/?snr=1_7_7_230_150_510
# 4    0.08182                            Collider        https://store.steampowered.com/app/371880/Collider/?snr=1_7_7_230_150_270
