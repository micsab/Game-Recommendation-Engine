# %%
import seaborn as sns
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup as soup, SoupStrainer
import requests
import lxml
from collections import Counter
from requests import exceptions
import os
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import steam
import pandas as pd
import numpy as np
from rake_nltk import Rake
import matplotlib.pyplot as plt; plt.rcdefaults()
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
from steam.api import interface
steam.api.key.set('FC864146AEF094845C669F86F0B20CFF')
pd.options.display.float_format = '{:,.5f}'.format
pd.set_option('display.max_colwidth', 80)
# %matplotlib inline

# %%
# Get title and links for all steam games
#urls = ['https://store.steampowered.com/search/?category1=998&page={}'.format(i) for i in range(1, 1185)]

filename = "products_v2.csv"
f = open(filename, "w", encoding="utf-8")
headers = "game_title\tsteam_url\n"
f.write(headers)

for url in urls:
    r = requests.get(url)
    page_soup = soup(r.content, "html.parser")

    containers = page_soup.findAll("a", {"class":"search_result_row ds_collapse_flag "})

    for container in containers:
        game_title = container.findAll("span", {"class":"title"})[0].text
        link = container["href"]

        #print(game_title)
        #print(link)
        #print("----------------")

        f.write(game_title + "\t" + link + "\n")

f.close()

# %% [markdown]
# # Don't Run This It'll Take Like a Million Hours#

# %%
#df_links = pd.read_csv('products_v2.csv', delimiter="\t")

tags = []
images = []
descriptions = []
num_reviews = []
rating_values = []
releases = []

cookies = {'birthtime': '568022401'}

for link in df_links.iterrows():
    print(link[1]['game_title'])
    url = link[1]['steam_url']
    r = requests.get(url, cookies=cookies)
    page_soup = soup(r.content, 'lxml')
    try:
        tag = page_soup.find("div", {"class":"glance_tags popular_tags"})
        tag = tag.text
        tag = tag.replace('\t', '').replace('\r', '').replace('\n', ', ').replace('+, ', '').replace(', , ', '')
        tags.append(tag)
    except:
        tag = 'no tags'
        tags.append(tag)
    
    try:
        image = page_soup.find('img', {'class':'game_header_image_full'})['src']
        images.append(image)
    except:
        image = 'no_image'
        images.append(image)
    
    try:
        num_review = int(page_soup.find('meta', {'itemprop':'reviewCount'})['content'])
        num_reviews.append(num_review)
    except:
        num_review = 'no reviews'
        num_reviews.append(num_review)

    try:
        rating_value = float(page_soup.find('meta', {'itemprop':'ratingValue'})['content'])
        rating_values.append(rating_value)
    except:
        rating_value = 'no rating'
        rating_values.append(rating_value)
    
    try:
        description = page_soup.find('div', {'class': 'game_description_snippet'}).text.replace('\t','').replace('\r','').replace('\n', '')
        descriptions.append(description)
    except:
        description = 'no description'
        descriptions.append(description)
        
    try:
        release = page_soup.find('div', {'class': 'date'}).text
        releases.append(release)
    except:
        release = 'no release date'
        releases.append(release)

        
        
    
      
the_rest = pd.DataFrame({'tags': tags, 'image': images, 'description': descriptions,
                         'number_of_review': num_reviews,
                         'score': rating_values,
                         'release_date': releases})

steam_scrape_the_rest = pd.concat([df_links, the_rest], axis=1, sort=False)
steam_scrape_the_rest.to_csv('steam_games_all_fields.csv', sep='\t')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-f0b7386d0a38> in <module>()
#      10 cookies = {'birthtime': '568022401'}
#      11
# ---> 12 for link in df_links.iterrows():
#      13     print(link[1]['game_title'])
#      14     url = link[1]['steam_url']
#
# NameError: name 'df_links' is not defined

# %%
steam_games = pd.read_csv('steam_games_all_fields.csv', index_col=0, delimiter='\t')
app_id = steam_games['steam_url'].str.split('/',expand=True)
app_id = app_id.drop([0, 1, 2, 5, 6], axis=1)
app_id.columns = ['app', 'game_ID']
df = pd.concat([steam_games, app_id], axis=1, sort=False)
df['description'] = df['description'].fillna('')
df = df[~df.description.str.contains('no description')]
df['release_date'] = df['release_date'].replace({'no release date' : ''})
df['game_title'] = df['game_title'].str.replace(r'®', '')
df['game_title'] = df['game_title'].str.replace(r'™', '')
df = df.drop(['app'], axis=1)
df['game_ID'] = pd.to_numeric(df['game_ID'], downcast='signed')
df['number_of_review'] = df['number_of_review'].replace({'no reviews' : ''})
df['number_of_review'] = pd.to_numeric(df['number_of_review'], downcast='integer')
df['score'] = df['score'].replace({'no rating' : ''})
df['score'] = pd.to_numeric(df['score'])
df = df[df['number_of_review'] > 0]
df = df.rename(columns={"game_ID": "appid"})
df = df.rename(columns={"Unnamed: 0": "id"})
#df = df.drop(['steam_url', 'image'], axis=1)
df = df.drop_duplicates(subset='appid', keep='first')
df = df.dropna(subset=['game_title'])
df = df.reset_index()
df.dtypes
# Out:
# index                 int64
# game_title           object
# steam_url            object
# tags                 object
# image                object
# description          object
# number_of_review    float64
# score               float64
# release_date         object
# appid                 int32
# dtype: object

# %%
text = " ".join(desc for desc in df.description)
print ("There are {} words in the combination of all descriptions.".format(len(text)))
stopwords = set(STOPWORDS)
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()
video_mask = np.array(Image.open(path.join(d, "video_game_mask.png")))
wc = WordCloud(stopwords=stopwords, background_color="black", max_words=10000,
                      contour_width=3, mask=video_mask, contour_color='white').generate(text)

wc.to_file(path.join(d, 'video_games.png'))

fig, ax = plt.subplots(figsize=(15, 10))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# There are 4213412 words in the combination of all descriptions.

# %%
text = " ".join(desc for desc in df.tags)
textlist = text.split(", ")
wordfreq = [textlist.count(w) for w in textlist]
pairs = Counter(text.split(", ")).most_common(25)
word = []
frequency = []

for i in range(len(pairs)):
    word.append(pairs[i][0])
    frequency.append(pairs[i][1])

indices = np.arange(len(pairs))
fig, ax = plt.subplots(figsize=(15, 10))
plt.bar(indices, frequency)
plt.title('Steam Tags by Count')
plt.xticks(indices, word, rotation='vertical')
plt.tight_layout()
plt.show()

# %%
sns.jointplot(x='number_of_review', y='score', data=df, height=10, color='g')
#plt.title('Steam Tags by Count')
#plt.xticks(indices, word, rotation='vertical')
plt.tight_layout()
plt.show()

# %%
my_steam_id = 76561197974553664
games = interface('IPlayerService').GetOwnedGames(steamid=my_steam_id, include_appinfo=1)
my_games = games['response']['games']
game_table = pd.DataFrame(my_games)
game_table = game_table.drop(['has_community_visible_stats', 'playtime_2weeks',
                              'img_icon_url', 'img_logo_url'], axis=1)
my_games_info = pd.merge(df, game_table, on='appid')
not_my_games = pd.merge(df, game_table, how='outer', on='appid')
not_my_games = not_my_games[not_my_games['playtime_forever'].isnull()]
not_my_games = not_my_games.drop(['name', 'image', 'playtime_forever'], axis=1)
not_my_games.head()
# Out:
#     index                                     game_title  \
# 1 1.00000                          MONSTER HUNTER: WORLD
# 2 2.00000                                  Path of Exile
# 3 3.00000                          Insurgency: Sandstorm
# 4 4.00000                                       Warframe
# 5 5.00000  Divinity: Original Sin 2 - Definitive Edition
#
#                                                                          steam_url  \
# 1  https://store.steampowered.com/app/582010/MONSTER_HUNTER_WORLD/?snr=1_7_7_23...
# 2     https://store.steampowered.com/app/238960/Path_of_Exile/?snr=1_7_7_230_150_1
# 3  https://store.steampowered.com/app/581320/Insurgency_Sandstorm/?snr=1_7_7_23...
# 4          https://store.steampowered.com/app/230410/Warframe/?snr=1_7_7_230_150_1
# 5  https://store.steampowered.com/app/435150/Divinity_Original_Sin_2__Definitiv...
#
#                                                                               tags  \
# 1  Action, Hunting, Co-op, Open World, Multiplayer, Third Person, RPG, Adventur...
# 2  Free to Play, Action RPG, Hack and Slash, RPG, Multiplayer, Massively Multip...
# 3  FPS, Realistic, Shooter, Multiplayer, Action, Military, Tactical, Singleplay...
# 4  Free to Play, Action, Co-op, Multiplayer, Third-Person Shooter, Sci-fi, Ninj...
# 5  RPG, Turn-Based, Co-op, Story Rich, Fantasy, Open World, Character Customiza...
#
#                                                                        description  \
# 1  Welcome to a new world! In Monster Hunter: World, the latest installment in ...
# 2  You are an Exile, struggling to survive on the dark continent of Wraeclast, ...
# 3  Insurgency: Sandstorm is a team-based, tactical FPS based on lethal close qu...
# 4  Warframe is a cooperative free-to-play third person online action game set i...
# 5  The eagerly anticipated sequel to the award-winning RPG. Gather your party. ...
#
#    number_of_review   score  release_date   appid  \
# 1      55,314.00000 6.00000   Aug 9, 2018  582010
# 2      74,977.00000 9.00000  Oct 23, 2013  238960
# 3       9,019.00000 9.00000  Dec 12, 2018  581320
# 4     236,593.00000 9.00000  Mar 25, 2013  230410
# 5      37,446.00000 9.00000  Sep 14, 2017  435150
#
#                                                                           tag_desc
# 1  Action, Hunting, Co-op, Open World, Multiplayer, Third Person, RPG, Adventur...
# 2  Free to Play, Action RPG, Hack and Slash, RPG, Multiplayer, Massively Multip...
# 3  FPS, Realistic, Shooter, Multiplayer, Action, Military, Tactical, Singleplay...
# 4  Free to Play, Action, Co-op, Multiplayer, Third-Person Shooter, Sci-fi, Ninj...
# 5  RPG, Turn-Based, Co-op, Story Rich, Fantasy, Open World, Character Customiza...

# %%
df_csno = my_games_info[~my_games_info.game_title.str.contains('Counter-Strike: Global Offensive')]
df_csno = df_csno[df_csno['playtime_forever'] <= 8000]

fig, ax = plt.subplots(figsize=(15, 10))
ax = sns.scatterplot(x="playtime_forever", y="number_of_review", hue="score", 
                     size= 'score', data=df_csno)

# %%
fig, ax = plt.subplots(figsize=(15, 10))
ax = sns.violinplot(x="score", y="playtime_forever", data=my_games_info)

# %%
tfidf_vec_desc = df[['index' ,'appid', 'game_title', 'tags', 'description']]
tf = TfidfVectorizer(analyzer='word', lowercase=True, ngram_range=(1, 3), min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(tfidf_vec_desc['description'])
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
results_desc = {}

for idx, row in tfidf_vec_desc.iterrows():
    similar_indices = cosine_similarities[idx].argsort()[:-1000:-1]
    similar_items = [(cosine_similarities[idx][i], tfidf_vec_desc['appid'][i]) for i in similar_indices]

    # First item is the item itself, so remove it.
    # Each dictionary entry is like: [(1,2), (3,4)], with each tuple being (score, item_id)
    results_desc[row['appid']] = similar_items[1:]
    
print('done!')
# Out:
# done!

# %%
def recommend(game, num):
    app_id = tfidf_vec_desc.loc[tfidf_vec_desc['game_title'] == game]['appid'].tolist()[0]
    
    print('Recommending ' + str(num) + " games sitting in your Steam library unplayed, that are similar to " + 
          game + '.')

    rez = results_desc[app_id]
    #print(rez)
    sim_score_df = pd.DataFrame(rez, columns=['sim_score', 'appid'])
    #print(df_test)
    my_game_df = pd.merge(sim_score_df, my_games_info, how='inner', on='appid')
    my_game_df = my_game_df.drop(['index', 'appid', 'number_of_review', 'release_date', 'name', 'score',
                                  'tags', 'description', 'steam_url', 'image'], axis = 1)
    my_game_df = my_game_df[my_game_df['playtime_forever'] <= 60]
    my_game_df = my_game_df.sort_values(['sim_score'], ascending=False)
    return my_game_df.head(num)

recommend('Rocket League', 5)
# Out:
# Recommending 5 games sitting in your Steam library unplayed, that are similar to Rocket League.
#    sim_score                             game_title  \
# 0    0.01548                Trine 2: Complete Story
# 1    0.01334                Trine Enchanted Edition
# 2    0.01242  Lead and Gold: Gangs of the Wild West
# 3    0.01100                                   BEEP
# 4    0.01046                     TrackMania² Canyon
#
#                                                                           tag_desc  \
# 0  Platformer, Adventure, Puzzle, Fantasy, Co-op, Indie, Online Co-Op, Local Co...
# 1  Platformer, Fantasy, Puzzle, Indie, Action, Local Co-Op, Co-op, Adventure, P...
# 2  Western, Action, Multiplayer, Third-Person Shooter, Third Person, Shooter Le...
# 3  Indie, Platformer, Adventure, Puzzle, Singleplayer, Physics, 2D, Action, Str...
# 4  Racing, Multiplayer, Level Editor, Time Attack, Sports, Arcade, Singleplayer...
#
#    playtime_forever
# 0                 0
# 1                 0
# 2                41
# 3                 7
# 4                 6

# %%
def recommend(game, num):
    app_id = tfidf_vec_desc.loc[tfidf_vec_desc['game_title'] == game]['appid'].tolist()[0]
    
    print('Fine, here are ' + str(num) + " games you could buy that are similar to " + 
          game + '.')

    rez = results_desc[app_id]
    #print(rez)
    sim_score_df = pd.DataFrame(rez, columns=['sim_score', 'appid'])
    #print(df_test)
    my_game_df = pd.merge(sim_score_df, not_my_games, how='inner', on='appid')
    my_game_df = my_game_df.drop(['index', 'appid', 'number_of_review', 'release_date', 'score',
                                  'tags', 'description'], axis = 1)
    #my_game_df = my_game_df[my_game_df['playtime_forever'] <= 60]
    my_game_df = my_game_df.sort_values(['sim_score'], ascending=False)
    return my_game_df.head(num)

recommend('Rocket League', 5)
# Out:
# Fine, here are 5 games you could buy that are similar to Rocket League.
#    sim_score               game_title  \
# 0    0.04882          Aerial Guardian
# 1    0.04827  Street Fighter X Tekken
# 2    0.04710                Blueshift
# 3    0.04594            Glider Island
# 4    0.04101              Rocket Fist
#
#                                                                          steam_url  \
# 0  https://store.steampowered.com/app/885730/Aerial_Guardian/?snr=1_7_7_230_150...
# 1  https://store.steampowered.com/app/209120/Street_Fighter_X_Tekken/?snr=1_7_7...
# 2       https://store.steampowered.com/app/565030/Blueshift/?snr=1_7_7_230_150_302
# 3   https://store.steampowered.com/app/500110/Glider_Island/?snr=1_7_7_230_150_248
# 4     https://store.steampowered.com/app/413500/Rocket_Fist/?snr=1_7_7_230_150_541
#
#                                                                           tag_desc
# 0  Early Access, Free to Play, Strategy, Early Access, Indie, Action, FPS Aeria...
# 1  Fighting, Action, Arcade, 2D Fighter, Multiplayer, Local Multiplayer, Local ...
# 2  Early Access, Free to Play, Racing, VR, Simulation, Casual, Indie, Early Acc...
# 3  Casual, Sports, Adventure, Simulation, Action, VR, Racing, Relaxing, Flight,...
# 4  Action, Indie, 4 Player Local Rocket Fist is an arena game with crazy robots...

# %%
count_vec_tags = df[['index' ,'appid', 'game_title', 'tags', 'description']]
vectorizer = CountVectorizer(analyzer='word', lowercase=True)
count_matrix = vectorizer.fit_transform(count_vec_tags['tags'])
cosine_similarities = cosine_similarity(count_matrix, count_matrix)

# %%
results_tags = {}

for idx, row in count_vec_tags.iterrows():
    similar_indices = cosine_similarities[idx].argsort()[:-1000:-1]
    similar_items = [(cosine_similarities[idx][i], count_vec_tags['appid'][i]) for i in similar_indices]

    # First item is the item itself, so remove it.
    # Each dictionary entry is like: [(1,2), (3,4)], with each tuple being (score, item_id)
    results_tags[row['appid']] = similar_items[1:]
    
print('done!')
# Out:
# done!

# %%
def recommend(game, num):
    app_id = count_vec_tags.loc[count_vec_tags['game_title'] == game]['appid'].tolist()[0]
    
    print('Recommending ' + str(num) + " games sitting in your Steam library unplayed, that are similar to " + 
          game + '.')

    rez = results_tags[app_id]
    #print(rez)
    sim_score_df = pd.DataFrame(rez, columns=['sim_score', 'appid'])
    #print(df_test)
    my_game_df = pd.merge(sim_score_df, my_games_info, how='inner', on='appid')
    my_game_df = my_game_df.drop(['index', 'appid', 'number_of_review', 'release_date', 'name', 'score',
                                  'tags', 'description', 'steam_url', 'image'], axis = 1)
    my_game_df = my_game_df[my_game_df['playtime_forever'] <= 60]
    my_game_df = my_game_df.sort_values(['sim_score'], ascending=False)
    return my_game_df.head(num)

recommend('Rocket League', 5)
# Out:
# Recommending 5 games sitting in your Steam library unplayed, that are similar to Rocket League.
#    sim_score                    game_title  playtime_forever
# 0    0.80016            Mount Your Friends                14
# 1    0.78824                 Lethal League                 0
# 3    0.74739       Trine 2: Complete Story                 0
# 4    0.73060  Monaco: What's Yours Is Mine                 0
# 5    0.71488    Awesomenauts - the 2D moba                 1

# %%
def recommend(game, num):
    app_id = count_vec_tags.loc[count_vec_tags['game_title'] == game]['appid'].tolist()[0]
    
    print('Fine, here are ' + str(num) + " games you could buy that are similar to " + 
          game + '.')

    rez = results_tags[app_id]
    #print(rez)
    sim_score_df = pd.DataFrame(rez, columns=['sim_score', 'appid'])
    #print(df_test)
    my_game_df = pd.merge(sim_score_df, not_my_games, how='inner', on='appid')
    my_game_df = my_game_df.drop(['index', 'appid', 'number_of_review', 'release_date', 'score',
                                  'tags', 'description'], axis = 1)
    #my_game_df = my_game_df[my_game_df['playtime_forever'] <= 60]
    my_game_df = my_game_df.sort_values(['sim_score'], ascending=False)
    return my_game_df.head(num)

recommend('Rocket League', 5)
# Out:
# Fine, here are 5 games you could buy that are similar to Rocket League.
#    sim_score             game_title  \
# 0    0.86017            Move or Die
# 1    0.84133                  Chase
# 2    0.84048          Overcooked! 2
# 3    0.83172                 Zero-G
# 4    0.81919  ROCKETSROCKETSROCKETS
#
#                                                                          steam_url
# 0      https://store.steampowered.com/app/323850/Move_or_Die/?snr=1_7_7_230_150_16
# 1           https://store.steampowered.com/app/867390/Chase/?snr=1_7_7_230_150_526
# 2      https://store.steampowered.com/app/728880/Overcooked_2/?snr=1_7_7_230_150_2
# 3           https://store.steampowered.com/app/567890/ZeroG/?snr=1_7_7_230_150_216
# 4  https://store.steampowered.com/app/289760/ROCKETSROCKETSROCKETS/?snr=1_7_7_2...

# %%
df['tag_desc'] = df[['tags', 'description']].apply(lambda x: ' '.join(x), axis=1)
tfidf_vec_tag_desc = df[['index' ,'appid', 'game_title', 'tag_desc']]
tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(tfidf_vec_tag_desc['tag_desc'])
cosine_similarities = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
results_tags_desc = {}

for idx, row in tfidf_vec_tag_desc.iterrows():
    similar_indices = cosine_similarities[idx].argsort()[:-1000:-1]
    similar_items = [(cosine_similarities[idx][i], tfidf_vec_tag_desc['appid'][i]) for i in similar_indices]

    # First item is the item itself, so remove it.
    # Each dictionary entry is like: [(1,2), (3,4)], with each tuple being (score, item_id)
    results_tags_desc[row['appid']] = similar_items[1:]
    
print('done!')
# Out:
# done!

# %%
def recommend(game, num):
    app_id = tfidf_vec_tag_desc.loc[tfidf_vec_tag_desc['game_title'] == game]['appid'].tolist()[0]
    
    print('Recommending ' + str(num) + " games sitting in your Steam library unplayed, that are similar to " + 
          game + '.')

    rez = results_tags_desc[app_id]
    #print(rez)
    sim_score_df = pd.DataFrame(rez, columns=['sim_score', 'appid'])
    #print(df_test)
    my_game_df = pd.merge(sim_score_df, my_games_info, how='inner', on='appid')
    my_game_df = my_game_df.drop(['index', 'appid', 'number_of_review', 'release_date', 'name', 'score',
                                  'tags', 'description', 'steam_url', 'image'], axis = 1)
    my_game_df = my_game_df[my_game_df['playtime_forever'] <= 60]
    my_game_df = my_game_df.sort_values(['sim_score'], ascending=False)
    return my_game_df.head(num)

recommend('Rocket League', 5)
# Out:
# Recommending 5 games sitting in your Steam library unplayed, that are similar to Rocket League.
#    sim_score                    game_title  \
# 2    0.05752       Trine 2: Complete Story
# 3    0.05685                 Lethal League
# 4    0.05460       Trine Enchanted Edition
# 6    0.05054  Monaco: What's Yours Is Mine
# 7    0.04901    Awesomenauts - the 2D moba
#
#                                                                           tag_desc  \
# 2  Platformer, Adventure, Puzzle, Fantasy, Co-op, Indie, Online Co-Op, Local Co...
# 3  Fighting, Local Multiplayer, 2D Fighter, Great Soundtrack, Indie, Multiplaye...
# 4  Platformer, Fantasy, Puzzle, Indie, Action, Local Co-Op, Co-op, Adventure, P...
# 6  Co-op, Stealth, Indie, Heist, Local Co-Op, Strategy, Online Co-Op, Top-Down,...
# 7  MOBA, Multiplayer, Platformer, 2D, Action, Indie, Local Co-Op, Co-op, Great ...
#
#    playtime_forever
# 2                 0
# 3                 0
# 4                 0
# 6                 0
# 7                 1

# %%
def recommend(game, num):
    app_id = tfidf_vec_tag_desc.loc[tfidf_vec_tag_desc['game_title'] == game]['appid'].tolist()[0]
    
    print('Fine, here are ' + str(num) + " games you could buy that are similar to " + 
          game + '.')

    rez = results_tags_desc[app_id]
    #print(rez)
    sim_score_df = pd.DataFrame(rez, columns=['sim_score', 'appid'])
    #print(df_test)
    my_game_df = pd.merge(sim_score_df, not_my_games, how='inner', on='appid')
    my_game_df = my_game_df.drop(['index', 'appid', 'number_of_review', 'release_date', 'score',
                                  'tags', 'description'], axis = 1)
    #my_game_df = my_game_df[my_game_df['playtime_forever'] <= 60]
    my_game_df = my_game_df.sort_values(['sim_score'], ascending=False)
    return my_game_df.head(num)

recommend('Rocket League', 5)
# Out:
# Fine, here are 5 games you could buy that are similar to Rocket League.
#    sim_score                          game_title  \
# 0    0.09753                            Collider
# 1    0.09172               Stick Fight: The Game
# 2    0.08907  Robot Roller-Derby Disco Dodgeball
# 3    0.08831       Lance A Lot: Enhanced Edition
# 4    0.08046                       Paddle Battle
#
#                                                                          steam_url  \
# 0        https://store.steampowered.com/app/371880/Collider/?snr=1_7_7_230_150_270
# 1  https://store.steampowered.com/app/674940/Stick_Fight_The_Game/?snr=1_7_7_23...
# 2  https://store.steampowered.com/app/270450/Robot_RollerDerby_Disco_Dodgeball/...
# 3  https://store.steampowered.com/app/684530/Lance_A_Lot_Enhanced_Edition/?snr=...
# 4   https://store.steampowered.com/app/655630/Paddle_Battle/?snr=1_7_7_230_150_510
#
#                                                                           tag_desc
# 0  Local Multiplayer, 4 Player Local, Casual, Indie, Great Soundtrack, Local Co...
# 1  Multiplayer, Funny, Fighting, Action, Local Multiplayer, 2D Fighter, 4 Playe...
# 2  Multiplayer, FPS, Fast-Paced, Indie, Great Soundtrack, Action, Robots, Sport...
# 3  Action, Indie, Casual, 4 Player Local, Local Multiplayer, Physics Challenge ...
# 4  Indie, Action, Sports, Local Multiplayer, 4 Player Local, Controller Paddle ...
