# %%
import steam
import pandas as pd
import numpy as np
from rake_nltk import Rake
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
from steam.api import interface
steam.api.key.set('FC864146AEF094845C669F86F0B20CFF')
pd.options.display.float_format = '{:,.2f}'.format

# %%
steam_games = pd.read_csv('steam_games_all_fields.csv', index_col=0, delimiter='\t')
app_id = steam_games['steam_url'].str.split('/',expand=True)
app_id = app_id.drop([0, 1, 2, 5, 6], axis=1)
app_id.columns = ['app', 'game_ID']
df = pd.concat([steam_games, app_id], axis=1, sort=False)
df['description'] = df['description'].fillna('')
df = df[~df.description.str.contains('no description')]
df['release_date'] = df['release_date'].replace({'no release date' : ''})
df = df.drop(['app'], axis=1)
df['game_ID'] = pd.to_numeric(df['game_ID'], downcast='signed')
df['number_of_review'] = df['number_of_review'].replace({'no reviews' : ''})
df['number_of_review'] = pd.to_numeric(df['number_of_review'], downcast='integer')
df['score'] = df['score'].replace({'no rating' : ''})
df['score'] = pd.to_numeric(df['score'])
df = df[df['number_of_review'] > 0]
#df = df[~df.game_title.str.contains('NaN')]
#df = df[~df.game_title.str.contains('NaN')]
df = df.rename(columns={"game_ID": "appid"})
df = df.rename(columns={"Unnamed: 0": "id"})
df = df.drop(['steam_url', 'image'], axis=1)
df = df.drop_duplicates(subset='appid', keep='first')
df = df.dropna(subset=['game_title'])
df = df.reset_index()
df.head(100)
# Out:
#     index                                         game_title  \
# 0       0                   Counter-Strike: Global Offensive
# 1       1                              MONSTER HUNTER: WORLD
# 2       2                                      Path of Exile
# 3       3                              Insurgency: Sandstorm
# 4       4                                           Warframe
# 5       5      Divinity: Original Sin 2 - Definitive Edition
# 6       6                          Assassin's Creed® Odyssey
# 7       7                                     Rocket League®
# 8       8                    Tom Clancy's Rainbow Six® Siege
# 9       9                                 Grand Theft Auto V
# 10     10                                    Team Fortress 2
# 11     11                      PLAYERUNKNOWN'S BATTLEGROUNDS
# 12     12                                               Rust
# 13     13                                     Stardew Valley
# 14     14                            Warhammer: Vermintide 2
# 15     15                                        War Thunder
# 16     16                            Total War: WARHAMMER II
# 17     17                          Kingdom Come: Deliverance
# 18     18                                              ATLAS
# 19     19                          Shadow of the Tomb Raider
# 20     20        The Elder Scrolls V: Skyrim Special Edition
# 21     21                                Black Desert Online
# 22     22                          The Witcher® 3: Wild Hunt
# 23     23                                      Slime Rancher
# 24     24                                   Dead by Daylight
# 25     25                                         The Forest
# 26     26                                         Beat Saber
# 27     27  DRAGON QUEST® XI: Echoes of an Elusive Age™ - ...
# 28     28                Tom Clancy's Ghost Recon® Wildlands
# 29     29                                               Raft
# ..    ...                                                ...
# 70     70             Nimbatus - The Space Drone Constructor
# 71     71                                               DOOM
# 72     72                                     Slay the Spire
# 73     73                                            Cuphead
# 74     74                           The Jackbox Party Pack 3
# 75     75                                      7 Days to Die
# 76     76                                       Pummel Party
# 77     77                                        SUPERHOT VR
# 78     78                                          Paladins®
# 79     79                                             Arma 3
# 80     80                                              Squad
# 81     81                                   Arizona Sunshine
# 82     82           Age of Empires® III: Complete Collection
# 83     83                                          Pavlov VR
# 84     84                               Kerbal Space Program
# 85     85                                      Hollow Knight
# 86     86                                       Conan Exiles
# 87     87                                           Factorio
# 88     88                              Don't Starve Together
# 89     89                            DARK SOULS™: REMASTERED
# 90     90                                           Yakuza 0
# 91     91                                      The Universim
# 92     92                                 Fallout: New Vegas
# 93     93                                    Shadowverse CCG
# 94     94                                   Human: Fall Flat
# 95     95                              Stick Fight: The Game
# 96     97                        Borderlands: The Pre-Sequel
# 97     98                                      Hunt Showdown
# 98     99                          Assassin's Creed® Origins
# 99    100                                       BeamNG.drive
#
#                                                  tags  \
# 0   FPS, Multiplayer, Shooter, Action, Team-Based,...
# 1   Action, Hunting, Co-op, Open World, Multiplaye...
# 2   Free to Play, Action RPG, Hack and Slash, RPG,...
# 3   FPS, Realistic, Shooter, Multiplayer, Action, ...
# 4   Free to Play, Action, Co-op, Multiplayer, Thir...
# 5   RPG, Turn-Based, Co-op, Story Rich, Fantasy, O...
# 6   Open World, Action, RPG, Singleplayer, Adventu...
# 7   Multiplayer, Racing, Soccer, Sports, Competiti...
# 8   FPS, Multiplayer, Tactical, Shooter, Action, T...
# 9   Open World, Action, Multiplayer, Third Person,...
# 10  Free to Play, Multiplayer, FPS, Action, Shoote...
# 11  Survival, Shooter, Multiplayer, PvP, Third-Per...
# 12  Survival, Crafting, Multiplayer, Open World, S...
# 13  RPG, Simulation, Pixel Graphics, Agriculture, ...
# 14  Co-op, Gore, First-Person, Multiplayer, Action...
# 15  Free to Play, World War II, Multiplayer, Simul...
# 16  Strategy, Fantasy, RTS, Grand Strategy, Turn-B...
# 17  Medieval, Open World, RPG, Realistic, Historic...
# 18  Early Access, Survival, Open World, Pirates, M...
# 19  Adventure, Action, Lara Croft, Female Protagon...
# 20  Open World, RPG, Adventure, Singleplayer, Fant...
# 21  Massively Multiplayer, MMORPG, Open World, RPG...
# 22  Open World, RPG, Story Rich, Atmospheric, Matu...
# 23  Cute, Exploration, Adventure, Colorful, First-...
# 24  Horror, Survival Horror, Multiplayer, Co-op, S...
# 25  Survival, Open World, Horror, Crafting, Advent...
# 26  Early Access, VR, Rhythm, Music, Indie, Early ...
# 27  RPG, JRPG, Turn-Based Combat, Singleplayer, An...
# 28  Open World, Shooter, Action, Multiplayer, Co-o...
# 29  Early Access, Survival, Crafting, Multiplayer,...
# ..                                                ...
# 70  Early Access, Indie, Action, Simulation, Space...
# 71  FPS, Action, Gore, Demons, Shooter, First-Pers...
# 72  Early Access, Card Game, Rogue-like, Turn-Base...
# 73  Difficult, Cartoon, Platformer, Great Soundtra...
# 74  Casual, Local Multiplayer, Funny, Board Game, ...
# 75  Early Access, Survival, Zombies, Open World, C...
# 76  Multiplayer, Casual, Indie, Board Game, Action...
# 77  Action, VR, Indie, Shooter, Bullet Time, FPS, ...
# 78  Free to Play, Multiplayer, FPS, Shooter, Actio...
# 79  Simulation, Military, Multiplayer, Realistic, ...
# 80  Early Access, FPS, Realistic, Military, Multip...
# 81  Zombies, VR, Action, Horror, Multiplayer, Gore...
# 82  Strategy, RTS, Base Building, Historical, Mult...
# 83  Early Access, VR, Action, Multiplayer, Early A...
# 84  Space, Simulation, Sandbox, Physics, Science, ...
# 85  Metroidvania, Great Soundtrack, Difficult, Pla...
# 86  Survival, Open World, Crafting, Nudity, Buildi...
# 87  Early Access, Base Building, Resource Manageme...
# 88  Survival, Multiplayer, Co-op, Open World, Adve...
# 89  Dark Fantasy, Difficult, Action, Action RPG, R...
# 90  Action, Story Rich, Beat 'em up, Open World, R...
# 91  Early Access, God Game, Simulation, Sandbox, C...
# 92  Open World, RPG, Post-apocalyptic, Singleplaye...
# 93  Free to Play, Card Game, Anime, Strategy, Trad...
# 94  Funny, Multiplayer, Co-op, Physics, Puzzle, Lo...
# 95  Multiplayer, Funny, Fighting, Action, Local Mu...
# 96  Co-op, Action, FPS, Comedy, Loot, RPG, Open Wo...
# 97  Early Access, Multiplayer, Online Co-Op, Survi...
# 98  Open World, Assassin, Action, Parkour, RPG, St...
# 99  Early Access, Simulation, Driving, Destruction...
#
#                                           description  number_of_review  \
# 0   Counter-Strike: Global Offensive (CS: GO) expa...      2,915,091.00
# 1   Welcome to a new world! In Monster Hunter: Wor...         55,314.00
# 2   You are an Exile, struggling to survive on the...         74,977.00
# 3   Insurgency: Sandstorm is a team-based, tactica...          9,019.00
# 4   Warframe is a cooperative free-to-play third p...        236,593.00
# 5   The eagerly anticipated sequel to the award-wi...         37,446.00
# 6   Choose your fate in Assassin's Creed® Odyssey....         14,907.00
# 7   Soccer meets driving once again in the long-aw...        182,330.00
# 8   Tom Clancy's Rainbow Six Siege is the latest i...        224,822.00
# 9   Los Santos is a city of bright lights, long ni...        386,027.00
# 10  Nine distinct classes provide a broad range of...        541,243.00
# 11  PLAYERUNKNOWN'S BATTLEGROUNDS is a battle roya...        800,693.00
# 12  The only aim in Rust is to survive. To do this...        196,406.00
# 13  You've inherited your grandfather's old farm p...         97,730.00
# 14  The sequel to the critically acclaimed Vermint...         20,574.00
# 15  War Thunder is the most comprehensive free-to-...        101,910.00
# 16  Strategy gaming perfected. A breath-taking cam...         13,099.00
# 17  Kingdom Come: Deliverance is a story-driven op...         24,392.00
# 18  ATLAS: The ultimate survival MMO of unpreceden...         17,351.00
# 19  As Lara Croft races to save the world from a M...          8,545.00
# 20  Winner of more than 200 Game of the Year Award...         12,634.00
# 21  Black Desert Online is a sandbox, living-world...         13,085.00
# 22  As war rages on throughout the Northern Realms...        177,721.00
# 23  Slime Rancher is the tale of Beatrix LeBeau, a...         19,756.00
# 24  Dead by Daylight is a multiplayer (4vs1) horro...        125,512.00
# 25  As the lone survivor of a passenger jet crash,...         96,179.00
# 26  Beat Saber is a VR rhythm game where your goal...          8,813.00
# 27  DRAGON QUEST® XI: Echoes of an Elusive Age™ fo...          2,022.00
# 28  Create a team with up to 3 friends in Tom Clan...         26,333.00
# 29  Raft throws you and your friends into an epic ...         10,991.00
# ..                                                ...               ...
# 70  Nimbatus - The Space Drone Constructor is an a...            245.00
# 71  Now includes all three premium DLC packs (Unto...         40,702.00
# 72  We fused card games and roguelikes together to...         21,750.00
# 73  Cuphead is a classic run and gun action game h...         34,049.00
# 74  The threequel to the party game phenomenon fea...            632.00
# 75  7 Days to Die is an open-world game that is a ...         52,330.00
# 76  Pummel Party is a 4-player online and local-mu...            694.00
# 77  Lose track of what’s real. Commit yourself, bo...          1,817.00
# 78  Join 25+ million players in Paladins, the free...        195,154.00
# 79  Experience true combat gameplay in a massive m...         78,678.00
# 80  Squad is a large scale combined arms multiplay...         20,274.00
# 81  Built exclusively for VR, Arizona Sunshine put...          3,028.00
# 82  Microsoft Studios brings you three epic Age of...         12,474.00
# 83  Pavlov is a multiplayer shooter for the HTC Vive.          2,649.00
# 84  In Kerbal Space Program, take charge of the sp...         43,598.00
# 85  Forge your own path in Hollow Knight! An epic ...         32,572.00
# 86  An open world survival game set in the lands o...         22,239.00
# 87  Factorio is a game about building and creating...         35,622.00
# 88  Don't Starve Together is the standalone multip...         64,920.00
# 89  Then, there was fire. Re-experience the critic...          9,212.00
# 90  SEGA’s legendary Japanese series finally comes...          6,723.00
# 91  Jump straight into managing your own planets a...          1,247.00
# 92      Welcome to Vegas. New Vegas. Enjoy your stay!         50,051.00
# 93  "One of my favorite games this year" - IGN Sha...          7,230.00
# 94  Human: Fall Flat is a quirky open-ended physic...         20,132.00
# 95  Stick Fight is a physics-based couch/online fi...         20,524.00
# 96  Launch into the Borderlands universe and shoot...         12,475.00
# 97  *EARLY ACCESS GAME* Hunt: Showdown is a compet...         20,020.00
# 98  ASSASSIN’S CREED® ORIGINS IS A NEW BEGINNING *...         31,356.00
# 99  A dynamic soft-body physics vehicle simulator ...         12,267.00
#
#     score  release_date   appid
# 0    9.00  Aug 21, 2012     730
# 1    6.00   Aug 9, 2018  582010
# 2    9.00  Oct 23, 2013  238960
# 3    9.00  Dec 12, 2018  581320
# 4    9.00  Mar 25, 2013  230410
# 5    9.00  Sep 14, 2017  435150
# 6    9.00   Oct 5, 2018  812140
# 7    9.00   Jul 7, 2015  252950
# 8    9.00   Dec 1, 2015  359550
# 9    6.00  Apr 14, 2015  271590
# 10   9.00  Oct 10, 2007     440
# 11   6.00  Dec 21, 2017  578080
# 12   9.00   Feb 8, 2018  252490
# 13  10.00  Feb 26, 2016  413150
# 14   7.00   Mar 8, 2018  552500
# 15   7.00  Aug 15, 2013  236390
# 16   9.00  Sep 28, 2017  594570
# 17   7.00  Feb 13, 2018  379430
# 18   5.00  Dec 22, 2018  834910
# 19   7.00  Sep 14, 2018  750920
# 20   9.00  Oct 27, 2016  489830
# 21   6.00  May 24, 2017  582660
# 22  10.00  May 18, 2015  292030
# 23  10.00   Aug 1, 2017  433340
# 24   7.00  Jun 14, 2016  381210
# 25   9.00  Apr 30, 2018  242760
# 26  10.00   May 1, 2018  620980
# 27   9.00   Sep 4, 2018  742120
# 28   7.00   Mar 6, 2017  460930
# 29   7.00  May 23, 2018  648800
# ..    ...           ...     ...
# 70   9.00   Oct 3, 2018  383840
# 71   9.00  May 12, 2016  379720
# 72  10.00  Nov 14, 2017  646570
# 73  10.00  Sep 29, 2017  268910
# 74   9.00  Oct 17, 2016  434170
# 75   7.00  Dec 13, 2013  251570
# 76   9.00  Sep 20, 2018  880940
# 77   9.00  May 25, 2017  617830
# 78   9.00   May 8, 2018  444090
# 79   9.00  Sep 12, 2013  107410
# 80   9.00  Dec 14, 2015  393380
# 81   9.00   Dec 6, 2016  342180
# 82   9.00  Sep 15, 2009  105450
# 83   9.00  Feb 27, 2017  555160
# 84   9.00  Apr 27, 2015  220200
# 85  10.00  Feb 24, 2017  367520
# 86   6.00   May 8, 2018  440900
# 87  10.00  Feb 25, 2016  427520
# 88  10.00  Apr 21, 2016  322330
# 89   6.00  May 23, 2018  570940
# 90   9.00   Aug 1, 2018  638970
# 91   7.00  Aug 28, 2018  352720
# 92  10.00  Oct 19, 2010   22380
# 93   7.00  Oct 27, 2016  453480
# 94   9.00  Jul 22, 2016  477160
# 95   9.00  Sep 28, 2017  674940
# 96   9.00  Oct 14, 2014  261640
# 97   7.00  Feb 22, 2018  594650
# 98   9.00  Oct 26, 2017  582160
# 99   9.00  May 29, 2015  284160
#
# [100 rows x 8 columns]

# %%
games = interface('IPlayerService').GetOwnedGames(steamid=76561197974553664, include_appinfo=1)
my_games = games['response']['games']
for game in my_games:
    game.update({"friend_ID": 76561197974553664})
    
game_table = pd.DataFrame(my_games)
#game_table = game_table.sort_values(by=['playtime_forever'], ascending=False)
#game_table = game_table.fillna(0)
game_table = game_table.drop(['has_community_visible_stats', 'friend_ID', 'name', 'playtime_2weeks',
                              'img_icon_url', 'img_logo_url'], axis=1)
game_table.head()
# Out:
#    appid  playtime_forever
# 0    220                57
# 1    240               237
# 2    320                 2
# 3    340                 0
# 4   1520               202

# %%
df = pd.merge(df, game_table, how='inner', on='appid')
df[13933:13935]
# Out:
# Empty DataFrame
# Columns: [game_title, id, tags, description, number_of_review, score, release_date, appid, playtime_forever_x, playtime_forever_y, playtime_forever_x, playtime_forever_y, playtime_forever]
# Index: []

# %%
ds = df[['index' ,'appid', 'game_title', 'tags', 'description']]
tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(ds['description'])

# %%
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
results = {}

for idx, row in ds.iterrows():
    similar_indices = cosine_similarities[idx].argsort()[:-100:-1]
    similar_items = [(cosine_similarities[idx][i], ds['index'][i]) for i in similar_indices]

    # First item is the item itself, so remove it.
    # Each dictionary entry is like: [(1,2), (3,4)], with each tuple being (score, item_id)
    results[row['index']] = similar_items[1:]
    
print('done!')
# Out:
# done!

# %%
def item(id):
    return ds.loc[ds['index'] == id]['game_title'].tolist()[0]

def recommend(item_id, num):
    print('Recommending ' + str(num) + " products similar to " + item(item_id) + '...')
    print('----------')
    recs = results[item_id][:num]
    for rec in recs:
        print('Recommended: ' + item(rec[1]) + " (score:" + str(rec[0]) + ")")
        
recommend(7, 10)
# Out:
# Recommending 10 products similar to Rocket League®...
# ----------
# Recommended: Aerial Guardian (score:0.0488233832084)
# Recommended: Street Fighter X Tekken (score:0.0482744368797)
# Recommended: Blueshift (score:0.0470963740242)
# Recommended: Glider Island (score:0.0459368708403)
# Recommended: Rocket Fist (score:0.041007012732)
# Recommended: Brawlerz Nitro (score:0.0390968172097)
# Recommended: Marvel's Guardians of the Galaxy: The Telltale Series (score:0.038686950824)
# Recommended: Draw Rider 2 (score:0.0373904947031)
# Recommended: LocoSoccer (score:0.0354869802524)
# Recommended: Heart's Medicine - Hospital Heat (score:0.0348884706921)

# %%
ds = df[['index' ,'appid', 'game_title', 'tags', 'description']]
tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(ds['tags'])
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
results = {}

for idx, row in ds.iterrows():
    similar_indices = cosine_similarities[idx].argsort()[:-100:-1]
    similar_items = [(cosine_similarities[idx][i], ds['index'][i]) for i in similar_indices]

    # First item is the item itself, so remove it.
    # Each dictionary entry is like: [(1,2), (3,4)], with each tuple being (score, item_id)
    results[row['index']] = similar_items[1:]
    
print('done!')
# Out:
# done!

# %%
def item(id):
    return ds.loc[ds['index'] == id]['game_title'].tolist()[0]

def recommend(item_id, num):
    print('Recommending ' + str(num) + " products similar to " + item(item_id) + '...')
    print('----------')
    recs = results[item_id][:num]
    for rec in recs:
        print('Recommended: ' + item(rec[1]) + " (score:" + str(rec[0]) + ")")
        
recommend(7, 10)
# Out:
# Recommending 10 products similar to Rocket League®...
# ----------
# Recommended: Squirrel Sphere (score:0.284562262601)
# Recommended: Domain Defense (score:0.238461181873)
# Recommended: 3..2..1..Grenades! (score:0.220414190373)
# Recommended: Chase (score:0.20626176021)
# Recommended: Robot Roller-Derby Disco Dodgeball (score:0.198512480378)
# Recommended: Drink 'Em (score:0.184775257461)
# Recommended: Coffin Dodgers (score:0.184612536812)
# Recommended: Stick Fight: The Game (score:0.183084290508)
# Recommended: Slimebrawl (score:0.180363517775)
# Recommended: Collider (score:0.175095816951)

# %%
ds = df[['game_title', 'tags', 'description']]
ds.head()
# Out:
#                          game_title  \
# 0  Counter-Strike: Global Offensive
# 1             MONSTER HUNTER: WORLD
# 2                     Path of Exile
# 3             Insurgency: Sandstorm
# 4                          Warframe
#
#                                                 tags  \
# 0  FPS, Multiplayer, Shooter, Action, Team-Based,...
# 1  Action, Hunting, Co-op, Open World, Multiplaye...
# 2  Free to Play, Action RPG, Hack and Slash, RPG,...
# 3  FPS, Realistic, Shooter, Multiplayer, Action, ...
# 4  Free to Play, Action, Co-op, Multiplayer, Thir...
#
#                                          description
# 0  Counter-Strike: Global Offensive (CS: GO) expa...
# 1  Welcome to a new world! In Monster Hunter: Wor...
# 2  You are an Exile, struggling to survive on the...
# 3  Insurgency: Sandstorm is a team-based, tactica...
# 4  Warframe is a cooperative free-to-play third p...

# %%
ds['tags'] = ds['tags'].map(lambda x: x.lower().split(','))
ds.head()
# Out:
# C:\Users\micsa\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                          game_title  \
# 0  Counter-Strike: Global Offensive
# 1             MONSTER HUNTER: WORLD
# 2                     Path of Exile
# 3             Insurgency: Sandstorm
# 4                          Warframe
#
#                                                 tags  \
# 0  [fps,  multiplayer,  shooter,  action,  team-b...
# 1  [action,  hunting,  co-op,  open world,  multi...
# 2  [free to play,  action rpg,  hack and slash,  ...
# 3  [fps,  realistic,  shooter,  multiplayer,  act...
# 4  [free to play,  action,  co-op,  multiplayer, ...
#
#                                          description
# 0  Counter-Strike: Global Offensive (CS: GO) expa...
# 1  Welcome to a new world! In Monster Hunter: Wor...
# 2  You are an Exile, struggling to survive on the...
# 3  Insurgency: Sandstorm is a team-based, tactica...
# 4  Warframe is a cooperative free-to-play third p...

# %%
# initializing the new column
ds['Key_words'] = ""

for index, row in ds.iterrows():
    plot = row['description']
    
    # instantiating Rake, by default is uses english stopwords from NLTK
    # and discard all puntuation characters
    r = Rake()

    # extracting the words by passing the text
    r.extract_keywords_from_text(plot)

    # getting the dictionary whith key words and their scores
    key_words_dict_scores = r.get_word_degrees()
    
    # assigning the key words to the new column
    row['Key_words'] = list(key_words_dict_scores.keys())

# dropping the Plot column
ds.drop(columns = ['description'], inplace = True)
# Out:
# C:\Users\micsa\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\micsa\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
ds.set_index('game_title', inplace = True)
ds.head(10)
# Out:
#                                                                                             tags  \
# game_title
# Counter-Strike: Global Offensive               [fps,  multiplayer,  shooter,  action,  team-b...
# MONSTER HUNTER: WORLD                          [action,  hunting,  co-op,  open world,  multi...
# Path of Exile                                  [free to play,  action rpg,  hack and slash,  ...
# Insurgency: Sandstorm                          [fps,  realistic,  shooter,  multiplayer,  act...
# Warframe                                       [free to play,  action,  co-op,  multiplayer, ...
# Divinity: Original Sin 2 - Definitive Edition  [rpg,  turn-based,  co-op,  story rich,  fanta...
# Assassin's Creed® Odyssey                      [open world,  action,  rpg,  singleplayer,  ad...
# Rocket League®                                 [multiplayer,  racing,  soccer,  sports,  comp...
# Tom Clancy's Rainbow Six® Siege                [fps,  multiplayer,  tactical,  shooter,  acti...
# Grand Theft Auto V                             [open world,  action,  multiplayer,  third per...
#
#                                                                                        Key_words
# game_title
# Counter-Strike: Global Offensive               [counter, team, go, features, new, maps, globa...
# MONSTER HUNTER: WORLD                          [monster, hunter, disposal, series, enjoy, hun...
# Path of Exile                                  [wraeclast, hardcore, gamers, dark, fantasy, w...
# Insurgency: Sandstorm                          [modern, combat, based, rewarded, team, skill,...
# Warframe                                       [play, third, person, online, action, game, se...
# Divinity: Original Sin 2 - Definitive Edition  [gather, winning, rpg, join, tactical, combat,...
# Assassin's Creed® Odyssey                      [outcast, creed, ®, odyssey, uncover, embark, ...
# Rocket League®                                 [score, amazing, aerial, goals, cars, superson...
# Tom Clancy's Rainbow Six® Siege                [person, shooter, franchise, developed, renown...
# Grand Theft Auto V                             [gta, online, bright, lights, dirtier, dirty, ...

# %%
ds['bag_of_words'] = ""
columns = ds.columns
for index, row in ds.iterrows():
    words = ''
    for col in columns:
        words = words + ' '.join(row[col])+ ' '
    row['bag_of_words'] = words
    
ds.drop(columns = [col for col in ds.columns if col!= 'bag_of_words'], inplace = True)
# Out:
# C:\Users\micsa\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\micsa\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
ds.head()
# Out:
#                                                                        bag_of_words
# game_title
# Counter-Strike: Global Offensive  fps  multiplayer  shooter  action  team-based ...
# MONSTER HUNTER: WORLD             action  hunting  co-op  open world  multiplaye...
# Path of Exile                     free to play  action rpg  hack and slash  rpg ...
# Insurgency: Sandstorm             fps  realistic  shooter  multiplayer  action  ...
# Warframe                          free to play  action  co-op  multiplayer  thir...

# %%
count = CountVectorizer()
count_matrix = count.fit_transform(ds['bag_of_words'])
indices = pd.Series(ds.index)
indices[:5]
# Out:
# 0    Counter-Strike: Global Offensive
# 1               MONSTER HUNTER: WORLD
# 2                       Path of Exile
# 3               Insurgency: Sandstorm
# 4                            Warframe
# Name: game_title, dtype: object

# %%
cosine_sim = cosine_similarity(count_matrix, count_matrix)
cosine_sim
# Out:
# array([[ 1.        ,  0.19249961,  0.23993603, ...,  0.        ,
#          0.12571132,  0.15880407],
#        [ 0.19249961,  1.        ,  0.41547448, ...,  0.09553946,
#          0.09007547,  0.12191496],
#        [ 0.23993603,  0.41547448,  1.        , ...,  0.13231403,
#          0.        ,  0.1823492 ],
#        ...,
#        [ 0.        ,  0.09553946,  0.13231403, ...,  1.        ,
#          0.16637807,  0.40533961],
#        [ 0.12571132,  0.09007547,  0.        , ...,  0.16637807,
#          1.        ,  0.12738595],
#        [ 0.15880407,  0.12191496,  0.1823492 , ...,  0.40533961,
#          0.12738595,  1.        ]])

# %%
def recommendations(title, cosine_sim=cosine_sim):
    recommended_games = []
    
    idx = indices[indices == title].index[0]
    
    score_series = pd.Series(cosine_sim[idx]).sort_values(ascending = False)
    
    top_10_indexes = list(score_series.iloc[0:11].index)
    
    for i in top_10_indexes:
        recommended_games.append(list(ds.index)[i])
        
    print(recommended_games, score_series)

# %%
recommendations('Rocket League®')
# Out:
# ['Rocket League®', 'Stick Fight: The Game', 'Move or Die', 'Sonic & All-Stars Racing Transformed Collection', 'Robot Roller-Derby Disco Dodgeball', 'Bloody Trapland', 'Overcooked', 'Zero-G', 'Hacktag', 'Trine 2: Complete Story', "Monaco: What's Yours Is Mine"] 7       1.00
# 95      0.61
# 393     0.61
# 730     0.60
# 1419    0.60
# 1812    0.59
# 330     0.58
# 5348    0.58
# 4481    0.57
# 1175    0.57
# 1711    0.57
# 335     0.56
# 76      0.56
# 5248    0.56
# 1141    0.56
# 3293    0.56
# 6711    0.55
# 42      0.55
# 1656    0.55
# 690     0.54
# 9110    0.54
# 2790    0.54
# 11357   0.54
# 1959    0.54
# 11709   0.54
# 8404    0.53
# 8466    0.53
# 756     0.53
# 1648    0.53
# 1190    0.53
#         ...
# 15532   0.00
# 19260   0.00
# 13382   0.00
# 9360    0.00
# 3424    0.00
# 3416    0.00
# 3412    0.00
# 7295    0.00
# 15526   0.00
# 13462   0.00
# 1594    0.00
# 19286   0.00
# 10314   0.00
# 10313   0.00
# 10234   0.00
# 7272    0.00
# 16716   0.00
# 13548   0.00
# 3271    0.00
# 6352    0.00
# 15451   0.00
# 1662    0.00
# 3255    0.00
# 19306   0.00
# 13599   0.00
# 1671    0.00
# 1674    0.00
# 15423   0.00
# 13608   0.00
# 13694   0.00
# Length: 20369, dtype: float64

# %%
score = pd.Series(cosine_sim[idx]).sort_values(ascending = False)
score
# Out:
# 0.99999999999999944

# %%
tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(ds['description'])
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
tf
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=0,
#         ngram_range=(1, 3), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words='english', strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
row
# Out:
# id                                                              29234
# appid                                                          886200
# game_title                                                EndCycle VS
# tags                        Early Access, Action, Indie, Early Access
# description         EndCycle VS is a multiplayer action-fighter th...
# description_keys    [player, battles, multiplayer, action, reflexe...
# Name: 20369, dtype: object

# %%
key_words_dict_scores
# Out:
# defaultdict(<function rake_nltk.rake.Rake._build_word_co_occurance_graph.<locals>.<lambda>()>,
#             {'player': 5,
#              'battles': 2,
#              'multiplayer': 2,
#              'action': 2,
#              'reflexes': 3,
#              'smart': 3,
#              'use': 3,
#              'battlefield': 1,
#              'vs': 3,
#              'unique': 3,
#              'attacks': 3,
#              '!!': 3,
#              'endcycle': 2,
#              'fighter': 1,
#              'winning': 3,
#              'fast': 3,
#              'combining': 2,
#              'strategy': 2})

# %%
ds = df[['id' ,'appid', 'game_title', 'tags', 'description']]
cs = ds['description'][0]

# %%
r = Rake()
r.extract_keywords_from_text(cs)
key_words_dict_scores = r.get_word_degrees()

# %%
ds[list(key_words_dict_scores.keys())
# Out:
# ['counter',
#  'team',
#  'go',
#  'features',
#  'new',
#  'maps',
#  'global',
#  'offensive',
#  'based',
#  'action',
#  'gameplay',
#  'strike',
#  'expands',
#  'upon',
#  'de_dust2',
#  'pioneered',
#  'delivers',
#  'updated',
#  'versions',
#  'game',
#  'modes',
#  'characters',
#  'weapons',
#  'etc',
#  'cs',
#  'classic',
#  'content',
#  ').',
#  'launched',
#  '19',
#  'years',
#  'ago']
