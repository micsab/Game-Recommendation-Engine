# %%
import pandas as pd
import numpy as np
from os import path
from collections import Counter
import os
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('steam_games_all_fields.csv', sep="\t", index_col=0)
df = df.dropna()
df = df[~df.description.str.contains('no description')]
df.dtypes
# Out:
# game_title          object
# steam_url           object
# tags                object
# image               object
# description         object
# number_of_review    object
# score               object
# release_date        object
# dtype: object

# %%
#steam_games_id[~steam_games_id.app.str.contains('digitalgiftcards')]

# %%
df[['game_title', 'description', 'number_of_review']].head()
# Out:
#                          game_title  \
# 0  Counter-Strike: Global Offensive
# 1             MONSTER HUNTER: WORLD
# 2                     Path of Exile
# 3             Insurgency: Sandstorm
# 4                          Warframe
#
#                                          description number_of_review
# 0  Counter-Strike: Global Offensive (CS: GO) expa...          2915091
# 1  Welcome to a new world! In Monster Hunter: Wor...            55314
# 2  You are an Exile, struggling to survive on the...            74977
# 3  Insurgency: Sandstorm is a team-based, tactica...             9019
# 4  Warframe is a cooperative free-to-play third p...           236593

# %%
# ?WordCloud

# %%
text = df.description[0]

# %%
df.description
# Out:
# 0        Counter-Strike: Global Offensive (CS: GO) expa...
# 1        Welcome to a new world! In Monster Hunter: Wor...
# 2        You are an Exile, struggling to survive on the...
# 3        Insurgency: Sandstorm is a team-based, tactica...
# 4        Warframe is a cooperative free-to-play third p...
# 5        The eagerly anticipated sequel to the award-wi...
# 6        Choose your fate in Assassin's Creed® Odyssey....
# 7        Soccer meets driving once again in the long-aw...
# 8        Tom Clancy's Rainbow Six Siege is the latest i...
# 9        Los Santos is a city of bright lights, long ni...
# 10       Nine distinct classes provide a broad range of...
# 11       PLAYERUNKNOWN'S BATTLEGROUNDS is a battle roya...
# 12       The only aim in Rust is to survive. To do this...
# 13       You've inherited your grandfather's old farm p...
# 14       The sequel to the critically acclaimed Vermint...
# 15       War Thunder is the most comprehensive free-to-...
# 16       Strategy gaming perfected. A breath-taking cam...
# 17       Kingdom Come: Deliverance is a story-driven op...
# 18       ATLAS: The ultimate survival MMO of unpreceden...
# 19       As Lara Croft races to save the world from a M...
# 20       Winner of more than 200 Game of the Year Award...
# 21       Black Desert Online is a sandbox, living-world...
# 22       As war rages on throughout the Northern Realms...
# 23       Slime Rancher is the tale of Beatrix LeBeau, a...
# 24       Dead by Daylight is a multiplayer (4vs1) horro...
# 25       As the lone survivor of a passenger jet crash,...
# 26       Beat Saber is a VR rhythm game where your goal...
# 27       DRAGON QUEST® XI: Echoes of an Elusive Age™ fo...
# 28       Create a team with up to 3 friends in Tom Clan...
# 29       Raft throws you and your friends into an epic ...
#                                ...
# 29301    Grab and grind to your heart’s content in Wave...
# 29302    Mr. Prepper is about to be prepared. You know ...
# 29303    Become an Alchemist; explore the Great Wildern...
# 29304    In Afterparty, you are Milo and Lola, recently...
# 29305    Realms Beyond is a party-based fantasy role-pl...
# 29306    A whimsical adventure/simulation game where yo...
# 29307    Nelly Cootalot is the stupidly named pirate ad...
# 29308    Yuyuko,A ghost princess who has been dead for ...
# 29309    The Occupation is a first-person, fixed-time, ...
# 29310    Orphan Age is a dystopian life sim game where ...
# 29311    Build your career as a Truck Driver! Haul a wi...
# 29312    Smalland is a survival game on a much larger s...
# 29313    Dive into one of the most vibrant environments...
# 29314    The Red Solstice is a top-down tactical surviv...
# 29315    Draugen is a single-player, first-person Fjord...
# 29316    Kitty Catsanova is the premier Idle Cat Dating...
# 29317    Become a true stick and rudder pilot and maste...
# 29318    Rainswept is an adventure game - A murder myst...
# 29319    The movement of our world has been adapted.Can...
# 29320    The hardest one-button rhythm game you will ev...
# 29321    In a world ravaged by war and dominated by mag...
# 29322    I'm not fat, I'm just a little...Husky. This t...
# 29323    This game is a purely placed game. The player ...
# 29324    Colonize a distant solar system in this compet...
# 29325    Become a true stick and rudder pilot and maste...
# 29326    Inspired by BioShock and System Shock 2, Void ...
# 29327    Defend Battle Station Osiris from the Galactic...
# 29328    Discover mysterious Aztec treasures in this ex...
# 29329    You are a traveling painter, exploring the isl...
# 29330    Irony Curtain: From Matryoshka with Love is a ...
# Name: description, Length: 29271, dtype: object

# %%
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
text = " ".join(desc for desc in df.description)
print ("There are {} words in the combination of all descriptions.".format(len(text)))
# Out:
# There are 5980934 words in the combination of all descriptions.

# %%
stopwords = set(STOPWORDS)

# %%
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()
video_mask = np.array(Image.open(path.join(d, "video_games.png")))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-11-c28be6af6413> in <module>()
#       1 d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()
# ----> 2 video_mask = np.array(Image.open(path.join(d, "video_games.png")))
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2620         fp.close()
#    2621     raise IOError("cannot identify image file %r"
# -> 2622                   % (filename if filename else fp))
#    2623
#    2624 #
#
# OSError: cannot identify image file 'C:\\Users\\micsa\\Documents\\thinkful_final\\Game-Recommendation-Engine\\video_games.png'

# %%
wc = WordCloud(stopwords=stopwords, width=800, height=400, background_color="white", max_words=10000,
                      mask=video_mask, contour_width=1, contour_color='white').generate(text)

wc.to_file(path.join(d, 'video_games.png'))

plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
counter = Counter(tags['steam_tags'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-e7fbfc07c385> in <module>()
# ----> 1 counter = Counter(tags['steam_tags'])
#
# NameError: name 'tags' is not defined

# %%
steamtags = tags['steam_tags']

# %%
text = " ".join(desc for desc in df.tags)

# %%
textlist = text.split(", ")

wordfreq = [textlist.count(w) for w in textlist]
    
#print("List\n" + str(textlist) + "\n")
#print("Frequencies\n" + str(wordfreq) + "\n")
#print("Pairs\n" + str(zip(textlist, wordfreq)))
pairs = Counter(text.split(", ")).most_common(25)
#sorted(pairs, key=lambda tup: tup[1])
pairs
# Out:
# [('Indie', 14753),
#  ('Adventure', 7993),
#  ('Action', 7766),
#  ('Casual', 7410),
#  ('Singleplayer', 5808),
#  ('Simulation', 4138),
#  ('Strategy', 3699),
#  ('RPG', 3629),
#  ('Early Access', 3219),
#  ('2D', 2767),
#  ('Great Soundtrack', 2704),
#  ('Multiplayer', 2640),
#  ('Atmospheric', 2557),
#  ('Puzzle', 2401),
#  ('Story Rich', 1850),
#  ('Difficult', 1630),
#  ('Platformer', 1623),
#  ('Violent', 1621),
#  ('Sci-fi', 1581),
#  ('Shooter', 1553),
#  ('Gore', 1506),
#  ('Pixel Graphics', 1496),
#  ('Funny', 1482),
#  ('Horror', 1434),
#  ('Female Protagonist', 1426)]

# %%
word = []
frequency = []

for i in range(len(pairs)):
    word.append(pairs[i][0])
    frequency.append(pairs[i][1])

indices = np.arange(len(pairs))
plt.bar(indices, frequency)
plt.title('Steam Tags by Count')
plt.xticks(indices, word, rotation='vertical')
plt.tight_layout()
plt.show()

# %%
Counter(text.split()).most_common(10)
# Out:
# [('Indie,', 20065),
#  ('Action,', 13349),
#  ('Adventure,', 11606),
#  ('Casual,', 9843),
#  ('Early', 7275),
#  ('Access,', 6540),
#  ('Strategy,', 6301),
#  ('Singleplayer,', 5795),
#  ('RPG,', 5379),
#  ('Simulation,', 5164)]

# %%
counter = Counter(text.split()).most_common(3)
tag_names = counter.keys()
tag_counts = counter.values()

indexes = np.arange(len(tag_names))
width = 0.7
plt.bar(indexes, tag_counts, width)
plt.xticks(indexes + width * 0.5, tag_names)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-c8295b8e740e> in <module>()
#       1 counter = Counter(text.split()).most_common(3)
# ----> 2 tag_names = counter.keys()
#       3 tag_counts = counter.values()
#       4
#       5 indexes = np.arange(len(tag_names))
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
tag_names
# Out:
# dict_keys(['FPS,', 'Multiplayer,', 'Shooter,', 'Action,', 'Team-Based,', 'Competitive,', 'Tactical,', 'First-Person,', 'e-sports,', 'PvP,', 'Online', 'Co-Op,', 'Military,', 'Co-op,', 'Strategy,', 'War,', 'Trading,', 'Difficult,', 'Realistic,', 'Fast-Paced,', 'Moddable', 'Hunting,', 'Open', 'World,', 'Third', 'Person,', 'RPG,', 'Adventure,', 'Fantasy,', 'Singleplayer,', 'Action', 'Character', 'Customization,', 'Great', 'Soundtrack,', 'Exploration,', 'Atmospheric,', 'JRPG,', 'Replay', 'Value,', 'Hack', 'and', 'Slash,', 'Souls-like', 'Free', 'to', 'Play,', 'Massively', 'Loot,', 'MMORPG,', 'Indie,', 'Dungeon', 'Crawler,', 'PvE,', 'Dark', 'Inventory', 'Management,', 'Fishing', 'Violent,', 'Gore,', 'Choices', 'Matter,', 'Indie', 'Third-Person', 'Sci-fi,', 'Ninja,', 'Parkour,', 'Space,', 'Futuristic,', 'Cyberpunk', 'Turn-Based,', 'Story', 'Rich,', 'Turn-Based', 'Combat,', 'CRPG,', 'Tactics,', 'Isometric,', 'Party-Based', 'Female', 'Protagonist', 'Assassin,', 'Historical,', 'Stealth,', 'Protagonist,', 'Sexual', 'Content,', 'Nudity,', 'Soundtrack', 'Racing,', 'Soccer,', 'Sports,', 'Football,', 'Local', 'Funny,', 'Split', 'Screen,', '4', 'Player', 'Local,', 'Casual,', 'Destruction,', 'Horror,', 'Physics,', 'Simulation,', 'Casual', 'Crime,', 'Mature,', 'Sandbox,', 'Comedy,', 'Moddable,', 'RPG', 'Class-Based,', 'Cartoony,', 'Robots,', 'Crafting,', 'Cartoon,', 'Survival,', 'Battle', 'Royale,', 'Early', 'Access,', 'Simulation', 'Building,', 'Post-apocalyptic,', 'Survival', 'Horror', 'Pixel', 'Graphics,', 'Agriculture,', 'Relaxing,', '2D,', 'Cute,', 'Dating', 'Sim,', 'Fishing,', 'Retro', 'Games', 'Workshop,', 'World', 'War', 'II,', 'Flight,', 'Tanks,', 'Arcade,', 'TrackIR', 'RTS,', 'Grand', 'Dinosaurs,', 'Real', 'Time', 'Content', 'Medieval,', 'Swordplay,', 'Choose', 'Your', 'Own', 'Horses,', 'Kickstarter,', 'Crowdfunded', 'Pirates,', 'Psychological', 'Base', 'Building', 'Lara', 'Croft,', 'Puzzle,', 'Action-Adventure,', 'Dark,', 'Heist', 'Dragons,', 'Magic,', 'Remake,', 'Classic,', 'Walking', 'Simulator,', 'Strategy', 'Multiple', 'Endings,', 'Sandbox', 'Colorful,', 'Family', 'Friendly,', 'FPS', 'Blood,', 'Difficult', 'Zombies,', 'VR,', 'Rhythm,', 'Music,', 'Star', 'Wars,', 'Anime,', 'PvP', 'Underwater,', 'Multiplayer', 'Board', 'Game,', 'Card', 'Chess,', 'Masterpiece,', 'Adventure', 'America,', 'MOBA,', 'Tower', 'Defense,', 'Aliens,', 'Play', 'Mythology,', 'Mining,', 'Procedural', 'Generation', 'Mod,', 'Animation', '&', 'Modeling,', 'City', 'Builder,', 'Steampunk,', 'Resource', 'Economy,', 'Real-Time', 'with', 'Pause,', 'Controller,', 'Generation,', 'Space', '4X,', 'Hex', 'Grid,', 'Atmospheric', 'Graphics', 'Memes,', 'Driving,', 'Lore-Rich,', 'Alternate', 'History', 'Quick-Time', 'Events', 'Violent', 'Funny', 'Rogue-like,', 'Metroidvania,', 'Rogue-lite,', 'Platformer,', 'Perma', 'Death,', 'Side', 'Scroller,', 'Souls-like,', 'Education,', 'Management', 'Sim', 'Crowdfunded,', 'Zombies', 'Puzzle-Platformer,', 'Retro,', 'Mystery,', 'Detective,', 'Naval,', 'Noir,', 'Simulator', 'History,', 'Diplomacy,', '3D', 'Co-op', 'Friendly', 'Rich', '4X', 'Demons,', 'Memes', 'Mouse', 'only,', 'Hand-drawn,', 'Bullet', 'Hell,', 'Shoot', "'Em", 'Up,', 'Gore', 'Beat', "'em", 'up,', 'Time,', 'First-Person', 'Real-Time,', 'Science,', 'Comedy', 'Gothic', 'Fantasy', 'Trains,', 'Defense', 'Rogue-like', 'Minigames,', 'Drama,', 'Anime', 'God', 'Western,', 'Person', 'Trading', 'Fighting,', '2D', 'Fighter,', 'Screen', 'Illuminati,', 'Swordplay', 'Co-Op', 'Romance,', 'Mechs,', '2.5D,', 'up', 'Basketball,', 'Singleplayer', 'Arcade', 'Arena', 'Competitive', 'Game', 'Gun', 'Realistic', 'Beautiful,', 'Dystopian', ',', 'Travel,', 'Linear,', 'Surreal,', 'Warhammer', '40K,', 'Sci-fi', 'Value', 'Supernatural,', 'Heist,', 'Illuminati', 'Design', 'Illustration,', 'VR', 'Twin', 'Stick', 'Matter', 'Mini', 'Golf,', 'Clicker', 'Silent', 'Access', 'Isometric', 'Stylized,', 'Humor,', 'Psychological,', 'Blood', 'Cyberpunk,', 'Modern,', 'MOBA', "1990's,", 'Platformer', 'no_tag', 'Stealth', ...
