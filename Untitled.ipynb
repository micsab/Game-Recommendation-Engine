# %%
import pandas as pd
import numpy as np
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('the_rest_of_the_fields.csv', sep="\t", index_col=0)
df = df.dropna()
df.dtypes
# Out:
# game_title          object
# steam_url           object
# description         object
# number_of_review    object
# score               object
# release_date        object
# dtype: object

# %%
#steam_games_id[~steam_games_id.app.str.contains('digitalgiftcards')]

df = df[~df.description.str.contains('no description')]
df.count()
# Out:
# game_title          24652
# steam_url           24652
# description         24652
# number_of_review    24652
# score               24652
# release_date        24652
# dtype: int64

# %%
df[['game_title', 'description', 'number_of_review']].head()
# Out:
#                          game_title  \
# 0  Counter-Strike: Global Offensive
# 1             MONSTER HUNTER: WORLD
# 2                     Path of Exile
# 3             Insurgency: Sandstorm
# 4                          Warframe
#
#                                          description number_of_review
# 0  Counter-Strike: Global Offensive (CS: GO) expa...          2908007
# 1  Welcome to a new world! In Monster Hunter: Wor...            54862
# 2  You are an Exile, struggling to survive on the...            74778
# 3  Insurgency: Sandstorm is a team-based, tactica...             8128
# 4  Warframe is a cooperative free-to-play third p...           236092

# %%
# ?WordCloud

# %%
text = df.description[0]

# %%
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
text = " ".join(desc for desc in df.description)
print ("There are {} words in the combination of all review.".format(len(text)))
# Out:
# There are 5077942 words in the combination of all review.

# %%
stopwords = set(STOPWORDS)

# %%
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
plt.imshow(wordcloud, interpolation='gaussian')
plt.axis('off')
plt.show()

# %%
df = pd.read_csv('gephi_test.csv')
df.sort_values(['Target'])
# Out:
#                  Source                                             Target
# 1944  76561197991610157  1... 2... 3... KICK IT! (Drop That Beat Like a...
# 4020  76561198034070553  1... 2... 3... KICK IT! (Drop That Beat Like a...
# 309   76561197972384491  1... 2... 3... KICK IT! (Drop That Beat Like a...
# 2314  76561197993235979  1... 2... 3... KICK IT! (Drop That Beat Like a...
# 4078  76561198034070553                                         10,000,000
# 2455  76561197993235979                                         10,000,000
# 4302  76561198034070553                                  100% Orange Juice
# 753   76561197978413983                                        1001 Spikes
# 4507  76561198034070553         12 Labours of Hercules II: The Cretan Bull
# 1199  76561197979975870                                                140
# 4526  76561198034070553                                       16bit Trader
# 2833  76561197993298262                                 1993 Space Machine
# 3106  76561197993699405                                 1993 Space Machine
# 4449  76561198034070553                           2064: Read Only Memories
# 3728  76561198029269257                                               20XX
# 4242  76561198034070553                      3089 -- Futuristic Action RPG
# 2461  76561197993235979                                             3DMark
# 4929  76561198036466697                                          3DMark 11
# 242   76561197972100809                                      7 Days to Die
# 4219  76561198034070553         7 Grand Steps, Step 1: What Ancients Begat
# 2125  76561197991610157                                       8-Bit Armies
# 2139  76561197991610157                                       8-Bit Hordes
# 628   76561197976404562                                            80 Days
# 4533  76561198034070553                                            80 Days
# 1744  76561197982933050                                       A Bird Story
# 4415  76561198034070553                                   A Fistful of Gun
